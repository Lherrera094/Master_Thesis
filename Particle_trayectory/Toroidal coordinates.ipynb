# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objects as go

# %%
# Define toroidal coordinates
theta = np.linspace(0, 2*np.pi, 100)
phi = np.linspace(0, 2*np.pi, 100)
theta, phi = np.meshgrid(theta, phi)
R = 1  # Major radius
r = 0.3  # Minor radius

# %%
# Convert toroidal coordinates to Cartesian coordinates
x = (R + r * np.cos(theta)) * np.cos(phi)
y = (R + r * np.cos(theta)) * np.sin(phi)
z = r * np.sin(theta)

# %%
# %matplotlib notebook
# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the torus
ax.plot_surface(x, y, z, cmap='viridis', alpha=0.8)

# Plot the toroidal axes
toroidal_axis_length = 1.5 * (R + r)
ax.plot([-toroidal_axis_length, toroidal_axis_length], [0, 0], [0, 0], 'k-', linewidth=2)
ax.plot([0, 0], [-toroidal_axis_length, toroidal_axis_length], [0, 0], 'k-', linewidth=2)
ax.plot([0, 0], [0, 0], [-r - toroidal_axis_length, -r + toroidal_axis_length], 'k-', linewidth=2)

# Set plot parameters
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Toroidal Coordinates')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1010.1666666666666">

# %%
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y, 
                                 colorscale="plasma_r", showscale=False)])

fig.show()
# Out:
# <div>                            <div id="1be2ea46-bac8-4817-a5d1-b9340634c29a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1be2ea46-bac8-4817-a5d1-b9340634c29a")) {                    Plotly.newPlot(                        "1be2ea46-bac8-4817-a5d1-b9340634c29a",                        [{"colorscale":[[0.0,"#f0f921"],[0.1111111111111111,"#fdca26"],[0.2222222222222222,"#fb9f3a"],[0.3333333333333333,"#ed7953"],[0.4444444444444444,"#d8576b"],[0.5555555555555556,"#bd3786"],[0.6666666666666666,"#9c179e"],[0.7777777777777778,"#7201a8"],[0.8888888888888888,"#46039f"],[1.0,"#0d0887"]],"showscale":false,"x":[[1.3,1.2993960029415654,1.2975864438492386,1.294578609178812,1.290384610418907,1.2850213353222837,1.2785103799048216,1.2708779614859864,1.2621548131
# ...
