# %%
from iota_Analysis_TK import *
import os

# %%
#Read From VMEC file
path = "wout_files/"
file = "wout_d3d_159243_00805.nc"
iota_df = read_VMEC_iota(path,file)
device = "DIII-D"

# %%
if not os.path.exists(device):
        os.makedirs(device)

# %%
#Gets maximum and minimum values of the iota profile
error = 0
i_M,i_m,resonant_modes = resonance_coupling(iota_df,error)
# Out:
# /home/armitage/Documents/Master/TFM/2. Iota Variation/Acoplos/iota_Analysis_TK.py:66: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_array_1 = new_array_1.append(new_row, ignore_index=True)

# %%
#Plots the iota profile
# %matplotlib notebook
plot_iota(iota_df,device)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#List all resonant modes
resonant_modes
# Out:
#         n      min_m       max_m      m  marker       n/m  n/m marked
# 0     1.0   2.946362    6.527094    3.0     4.0  0.333333    0.333333
# 19    1.0   2.946362    6.527094    6.0     4.0  0.166667    0.333333
# 18    1.0   2.946362    6.527094    5.0     4.0  0.200000    0.333333
# 17    1.0   2.946362    6.527094    4.0     4.0  0.250000    0.333333
# 26    2.0   5.892724   13.054188   13.0     8.0  0.153846    0.333333
# ..    ...        ...         ...    ...     ...       ...         ...
# 512  17.0  50.088155  110.960602   75.0    60.0  0.226667    0.333333
# 513  17.0  50.088155  110.960602   76.0    60.0  0.223684    0.333333
# 514  17.0  50.088155  110.960602   77.0    60.0  0.220779    0.333333
# 516  17.0  50.088155  110.960602   79.0    60.0  0.215190    0.333333
# 547  17.0  50.088155  110.960602  110.0    60.0  0.154545    0.333333
#
# [548 rows x 7 columns]

# %%
print(f"Total Resonant Modes: {len(resonant_modes)}")
# Out:
# Total Resonant Modes: 548

# %%
#call of functions
iota_df = read_data_iota(i)
i_M,i_m,couplings = resonance_coupling(iota_df,error)
couplings.to_excel(f"{i}/Full_coupling_list.xlsx",index=False)
plot_iota(iota_df,i)
plot_resonant_modes(couplings,periods,i,pos[2],iota_df,size)

# %%
plot_all_iota(iota)
